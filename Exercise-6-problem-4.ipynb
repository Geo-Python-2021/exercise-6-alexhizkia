# %% [markdown]
# # Problem 4 (optional)
#
# Calculating weather anomalies for another location. In this optional task you get to start from scratch and download the data yourself from NOAA.
#
# ## What to do
#
# 1. Start by downloading your own data (daily summaries for years **1959-2018 August**) for **Sodankyla Lokka** (notice the place name should be without the letter `ä`), from the [NOAA Climate Data Online Search](https://www.ncdc.noaa.gov/cdo-web/search?datasetid=GHCND). Make sure to select the starting day (and ending day) in the date selection panel after changing the year! After you have searched, click “Add to cart” for a selected station, then go to the cart. Select the ``Custom GHCN-Daily Text`` format for the resulting output file and hit continue.
#
#     - From the `Station Detail & Data Flag Options` choose two of the following attributes: Station Name, Geographic Location. **Notice:** Do **NOT** include data flags because it makes the data difficult to read. Use **Standard** units.
#     - Take also Precipitation and Temperature which are under a separate button below.
#     - From the next page, add your own email address where the weather data will be sent after a short moment.
#
# 2. After you have downloaded the data. you should first,
#
#     - Calculate the average temperature using columns `TMAX` and `TMIN` and insert those values into a new column called `TAVG`.
#
# 3. Next, you should use the approaches learned during this week and used in Problem 3 to answer / do the following:
#
#     - Calculate the temperature anomalies in Sodankylä, i.e., the difference between `reference_temps` and the average temperature for each month (see Problem 3).
#     - Calculate the monthly temperature differences between the Sodankylä and Helsinki stations
#         - How different are the summer temperatures (June, July, August) between Helsinki (used in Problems 1-3) and Sodankylä?
#         - What were the summer mean temperatures for both of these stations?
#         - What were the summer standard deviations for both of these stations?
#     - Calculate the monthly differences in a DataFrame and save it (as `CSV` file) into your own Exercise repository for this week
# 4. Upload your notebook and data to GitHub

# %%
import pandas as pd
data = pd.read_fwf('data/data.txt', colspecs=[(0,17),(17,68),(68,79),(79,90),(90,101),(101,110),(110,119),(119,128),(128,137)],skiprows=[1], na_values=[-9999])
data.shape
# Out:
# (20912, 9)

# %%
data.head()
# Out:
#              STATION        STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 1  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 2  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 3  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 4  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
#
#        DATE  PRCP  TMAX  TMIN
# 0  19590101  0.03   NaN   9.0
# 1  19590102  0.00   NaN   6.0
# 2  19590103  0.02   NaN  -9.0
# 3  19590104  0.08   NaN  10.0
# 4  19590105  0.09   NaN  13.0

# %%
data['TAVG']= 0.0
for idx, row in data.iterrows():
    minus_temp= (row['TMAX'] + row['TMIN']) / 2
    data.at[idx, 'TAVG'] = minus_temp

# %%
data.head()
# Out:
#              STATION        STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 1  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 2  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 3  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 4  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
#
#        DATE  PRCP  TMAX  TMIN  TAVG
# 0  19590101  0.03   NaN   9.0   NaN
# 1  19590102  0.00   NaN   6.0   NaN
# 2  19590103  0.02   NaN  -9.0   NaN
# 3  19590104  0.08   NaN  10.0   NaN
# 4  19590105  0.09   NaN  13.0   NaN

# %%
data.tail()
# Out:
#                  STATION        STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 20907  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 20908  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 20909  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 20910  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 20911  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
#
#            DATE  PRCP  TMAX  TMIN  TAVG
# 20907  20180827  0.04  55.0  43.0  49.0
# 20908  20180828  0.00  59.0  31.0  45.0
# 20909  20180829  0.00  65.0  32.0  48.5
# 20910  20180830  0.02  65.0  48.0  56.5
# 20911  20180831  0.00  59.0  46.0  52.5

# %%
from temp_functions import fahr_to_celsius

# %%
data['temp_celsius'] = data['TAVG'].apply(fahr_to_celsius)

# %%
data.head()
# Out:
#              STATION        STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 1  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 2  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 3  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 4  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
#
#        DATE  PRCP  TMAX  TMIN  TAVG  temp_celsius
# 0  19590101  0.03   NaN   9.0   NaN           NaN
# 1  19590102  0.00   NaN   6.0   NaN           NaN
# 2  19590103  0.02   NaN  -9.0   NaN           NaN
# 3  19590104  0.08   NaN  10.0   NaN           NaN
# 4  19590105  0.09   NaN  13.0   NaN           NaN

# %%
avg_temp_1969_sodankyla = data.loc[(data['DATE'] >= 19690601) & (data['DATE'] <= 19690831), 'TMAX'].mean()
round(avg_temp_1969_sodankyla,2)
# Out:
# 60.66

# %%
data['DATE_STR']= data['DATE'].astype(str)
data['YEAR_MONTH']= data['DATE_STR'].str.slice(start=0, stop=6)
data.head()
# Out:
#              STATION        STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 1  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 2  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 3  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 4  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
#
#        DATE  PRCP  TMAX  TMIN  TAVG  temp_celsius  DATE_STR YEAR_MONTH
# 0  19590101  0.03   NaN   9.0   NaN           NaN  19590101     195901
# 1  19590102  0.00   NaN   6.0   NaN           NaN  19590102     195901
# 2  19590103  0.02   NaN  -9.0   NaN           NaN  19590103     195901
# 3  19590104  0.08   NaN  10.0   NaN           NaN  19590104     195901
# 4  19590105  0.09   NaN  13.0   NaN           NaN  19590105     195901

# %%
data['month'] = data['YEAR_MONTH'].str.slice(start=4, stop=6).astype(float)
data.head()
# Out:
#              STATION        STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 1  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 2  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 3  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
# 4  GHCND:FIE00146538  SODANKYLA LOKKA FI        240   67.8206    27.7503
#
#        DATE  PRCP  TMAX  TMIN  TAVG  temp_celsius  DATE_STR YEAR_MONTH  month
# 0  19590101  0.03   NaN   9.0   NaN           NaN  19590101     195901    1.0
# 1  19590102  0.00   NaN   6.0   NaN           NaN  19590102     195901    1.0
# 2  19590103  0.02   NaN  -9.0   NaN           NaN  19590103     195901    1.0
# 3  19590104  0.08   NaN  10.0   NaN           NaN  19590104     195901    1.0
# 4  19590105  0.09   NaN  13.0   NaN           NaN  19590105     195901    1.0

# %%
monthly_data = data.groupby(['YEAR_MONTH'], as_index=False)['TAVG', 'TMAX', 'TMIN', 'temp_celsius', 'month'].mean()

data['ref_temp'] = data['temp_celsius']
reference_temp = data.groupby(['month'], as_index=False)['ref_temp'].mean()
# Out:
# C:\Users\COMPUTER\AppData\Local\Temp/ipykernel_20928/2487087158.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   monthly_data = data.groupby(['YEAR_MONTH'], as_index=False)['TAVG', 'TMAX', 'TMIN', 'temp_celsius', 'month'].mean()

# %%
monthly_data = monthly_data.merge(reference_temp, on='month', how='outer')
monthly_data.tail()
# Out:
#     YEAR_MONTH       TAVG       TMAX      TMIN  temp_celsius  month   ref_temp
# 682     201312  14.451613  22.935484  5.967742     -9.749104   12.0 -12.353487
# 683     201412  14.741935  20.225806  9.258065     -9.587814   12.0 -12.353487
# 684     201512  12.983871  22.483871  3.483871    -10.564516   12.0 -12.353487
# 685     201612  13.338710  22.935484  3.741935    -10.367384   12.0 -12.353487
# 686     201712  12.387097  20.354839  4.419355    -10.896057   12.0 -12.353487

# %%
monthly_data['diff'] = monthly_data['temp_celsius'] - monthly_data['ref_temp']

# %%
monthly_data.sort_values(by='YEAR_MONTH', ascending=True)
# Out:
#     YEAR_MONTH       TAVG       TMAX       TMIN  temp_celsius  month  \
# 0       195901        NaN        NaN  -5.000000           NaN    1.0
# 57      195902        NaN        NaN  12.000000           NaN    2.0
# 114     195903        NaN        NaN  15.000000           NaN    3.0
# 171     195904        NaN        NaN  10.833333           NaN    4.0
# 228     195905  41.467742  49.935484  33.000000      5.259857    5.0
# ..         ...        ...        ...        ...           ...    ...
# 227     201804  28.733333  37.633333  19.833333     -1.814815    4.0
# 284     201805  46.822581  58.000000  35.645161      8.234767    5.0
# 342     201806  49.733333  57.433333  42.033333      9.851852    6.0
# 400     201807  63.870968  76.709677  51.032258     17.706093    7.0
# 458     201808  54.516129  62.483871  46.548387     12.508961    8.0
#
#       ref_temp      diff
# 0   -14.682860       NaN
# 57  -14.127360       NaN
# 114  -9.549372       NaN
# 171  -3.118221       NaN
# 228   3.883698  1.376158
# ..         ...       ...
# 227  -3.118221  1.303406
# 284   3.883698  4.351069
# 342  10.388250 -0.536398
# 400  13.543869  4.162224
# 458  10.975930  1.533031
#
# [687 rows x 8 columns]

# %%
helsinki_data = pd.read_csv('helsinki_temp.csv')
del helsinki_data['Unnamed: 0']
helsinki_data.tail()
# Out:
#      YEAR_MONTH       TAVG       TMAX       TMIN  temp_celsius  month  \
# 785      201212  20.064516  24.096774  15.548387     -6.630824   12.0
# 786      201312  34.451613  37.935484  30.161290      1.362007   12.0
# 787      201412  29.935484  33.580645  23.838710     -1.146953   12.0
# 788      201512  35.967742  40.225806  30.322581      2.204301   12.0
# 789      201612  30.580645  34.548387  25.838710     -0.788530   12.0
#
#      ref_temp      diff
# 785 -3.203887 -3.426938
# 786 -3.203887  4.565894
# 787 -3.203887  2.056933
# 788 -3.203887  5.408188
# 789 -3.203887  2.415356

# %%
helsinki_sorted = helsinki_data.sort_values(by='YEAR_MONTH', ascending=True)

# %%
helsinki_sorted = helsinki_data.reset_index(drop=True)

# %%
avg_temp_helsinki = helsinki_data.loc[(data['DATE'] >= 196905) & (data['DATE'] <= 19690831), 'temp_celsius'].mean()
avg_temp_helsinki

# %%
sodankyla_data = monthly_data.sort_values(by='YEAR_MONTH', ascending=True)

# %%
sodankyla_data= sodankyla_data.reset_index(drop=True)

# %%
sodankyla_data.head()
